# %%
import numpy as np
import pandas as pd 

import warnings 
warnings.filterwarnings('ignore')

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(style='white', color_codes=True)

# %%
df= pd.read_csv('C://Users//admin//Downloads//iris.csv')

# %%
df
# Out:
#       ID  Sepal Length  Sepal Width  Petal Length  Petal Width         Species
# 0      1           5.1          3.5           1.4          0.2     Iris-setosa
# 1      2           4.9          3.0           1.4          0.2     Iris-setosa
# 2      3           4.7          3.2           1.3          0.2     Iris-setosa
# 3      4           4.6          3.1           1.5          0.2     Iris-setosa
# 4      5           5.0          3.6           1.4          0.2     Iris-setosa
# ..   ...           ...          ...           ...          ...             ...
# 145  146           6.7          3.0           5.2          2.3  Iris-virginica
# 146  147           6.3          2.5           5.0          1.9  Iris-virginica
# 147  148           6.5          3.0           5.2          2.0  Iris-virginica
# 148  149           6.2          3.4           5.4          2.3  Iris-virginica
# 149  150           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.head(10)
# Out:
#    ID  Sepal Length  Sepal Width  Petal Length  Petal Width      Species
# 0   1           5.1          3.5           1.4          0.2  Iris-setosa
# 1   2           4.9          3.0           1.4          0.2  Iris-setosa
# 2   3           4.7          3.2           1.3          0.2  Iris-setosa
# 3   4           4.6          3.1           1.5          0.2  Iris-setosa
# 4   5           5.0          3.6           1.4          0.2  Iris-setosa
# 5   6           5.4          3.9           1.7          0.4  Iris-setosa
# 6   7           4.6          3.4           1.4          0.3  Iris-setosa
# 7   8           5.0          3.4           1.5          0.2  Iris-setosa
# 8   9           4.4          2.9           1.4          0.2  Iris-setosa
# 9  10           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                ID  Sepal Length  Sepal Width  Petal Length  Petal Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.054000      3.758667     1.198667
# std     43.445368      0.828066     0.433594      1.764420     0.763161
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind='scatter',x='Sepal Length', y='Sepal Width')
# Out:
# <Axes: xlabel='Sepal Length', ylabel='Sepal Width'>

# %%
sns.jointplot(x='Sepal Length',y='Sepal Width', data=df, size=5)

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ID            150 non-null    int64
#  1   Sepal Length  150 non-null    float64
#  2   Sepal Width   150 non-null    float64
#  3   Petal Length  150 non-null    float64
#  4   Petal Width   150 non-null    float64
#  5   Species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.FacetGrid(df, hue = 'Species', height=5, aspect=1.5) \
    .map(plt.scatter, 'Sepal Length','Sepal Width') \
    .add_legend()

# %%
sns.boxplot(x='Species', y='Petal Length', data=df)
# Out:
# <Axes: xlabel='Species', ylabel='Petal Length'>

# %%
ax = sns.boxplot(data=df, x = 'Species',y = 'Petal Length')
ax = sns.stripplot(data=df, x='Species', y='Petal Length', jitter=True, edgecolor='green')

# %%
sns.violinplot(x='Species',y='Petal Length', data=df, size=6)
# Out:
# <Axes: xlabel='Species', ylabel='Petal Length'>

# %%
sns.FacetGrid(df, hue="Species", height=4, aspect=1.5) \
   .map(sns.kdeplot, "Petal Length") \
   .add_legend()

# %%
sns.pairplot(df.drop('ID', axis=1), hue='Species', size=3)

# %%
df.drop('ID', axis=1).boxplot(by='Species', figsize=(12,6))
# Out:
# array([[<Axes: title={'center': 'Petal Length'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'Petal Width'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'Sepal Length'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'Sepal Width'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
pd.plotting.andrews_curves(df.drop("ID", axis=1), "Species")
plt.show()

# %%
sns.catplot(x='Sepal Length', data=df, hue='Species', kind='count', height=4.5, aspect=1.7)
